# %%
import matplotlib.pyplot as plt
plt.plot([1, 10, 50, 100, 500, 1000], [1.05, 1.09, 1.10, 1.09, 1.11, 1.10] , 's-', linewidth=2, markersize=5,label="1 hilo")
plt.plot([1, 10, 50, 100, 500, 1000], [1.48, 1.87, 2.02, 1.98, 2.05, 2.03] , 's-', linewidth=2, markersize=5,label="2 hilos")
plt.plot([1, 10, 50, 100, 500, 1000], [2.19, 2.24, 2.28, 2.19, 2.22, 2.16] , 's-', linewidth=2, markersize=5,label="4 hilos")
plt.plot([1, 10, 50, 100, 500, 1000], [2.16, 2.26, 2.28, 2.20, 2.22, 2.15] , 's-', linewidth=2, markersize=5,label="8 hilos")
plt.ylabel('SpeedUp')
plt.xlabel('Iteraciones')
plt.title('Speed Up para 1, 2, 4 y 8 hilos')
plt.legend()
plt.show()

# %%
plt.plot([1, 2, 4, 8], [0.002652519894, 0.002339181287, 0.000331180659, 0.0004734848485] , 's--', linewidth=2, markersize=5)
plt.ylabel('SpeedUp')
plt.xlabel('Threads')
plt.title('Speed Up para 1,2,4 y 8 hilos con p = 10')
plt.show()
